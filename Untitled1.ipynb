# %%
import tensorflow as tf
import keras
import cv2
import numpy as np
import urllib.request
import matplotlib.pyplot as plt
from keras.datasets import cifar10
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPooling2D
from keras.layers import Dropout, Flatten, BatchNormalization
from keras.regularizers import l2
from keras.callbacks import ReduceLROnPlateau, EarlyStopping
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size = 0.1, random_state = 101)

# %%
X_train.shape, y_valid.shape, X_test.shape
# Out:
# ((45000, 32, 32, 3), (5000, 1), (10000, 32, 32, 3))

# %%
 class_names = ['airplane ','automobile ','bird ','cat ','deer ','dog ','frog ','horse ','ship ','truck']

# %%
plt.figure(figsize=(15, 15))

for i in range(64):
    plt.subplot(8, 8, i+1)
    plt.imshow(X_train[i])
    plt.xticks([])
    plt.yticks([])
    plt.imshow(X_train[i])
    plt.title(class_names[y_train[i][0]])

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Data preprocessing
#
# 1. Normalization of images
# 2. One hot encoding of labels
# 3. Data Augmentation

# %% [markdown]
# ### Normalisation

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_valid = X_valid.astype('float32')

mean = np.mean(X_train)
std = np.std(X_train)
# X_train = X_train / 255
# X_test = X_test / 255
# X_valid = X_valid / 255
X_train = (X_train-mean)/(std+.00000001)
X_test = (X_test-mean)/(std+.00000001)
X_valid = (X_valid-mean)/(std+.00000001)

# %%
### One hot encoding

# %%
y_train = to_categorical(y_train,10 )
y_test = to_categorical(y_test,10 )
y_valid = to_categorical(y_valid,10 )

# %%
### Data Augmentation

# %%
data_generator = ImageDataGenerator(
    rotation_range = 15,
    width_shift_range = 0.12,
    height_shift_range = 0.12,
    horizontal_flip = True,
    zoom_range = 0.1,
    brightness_range = [0.9, 1.1],
    shear_range = 10,
    channel_shift_range = 0.1

)

# %% [markdown]
# ### Model

# %%
model = Sequential()

weight_decay = 0.0001   # weight decay for l2 regularization

# 1st layer
model.add(Conv2D(filters = 32, kernel_size =(3,3), padding ='same', activation ='relu', kernel_regularizer = l2(weight_decay), input_shape = X_train.shape[1:]))
model.add(BatchNormalization())
model.add(Conv2D(filters = 32, kernel_size =(3,3), padding ='same', activation ='relu', kernel_regularizer = l2(weight_decay)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(rate = 0.2))

# 2nd layer
model.add(Conv2D(filters = 64, kernel_size =(3,3), padding ='same', activation ='relu', kernel_regularizer = l2(weight_decay)))
model.add(BatchNormalization())
model.add(Conv2D(filters = 64, kernel_size =(3,3), padding ='same', activation ='relu', kernel_regularizer = l2(weight_decay)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(rate = 0.3))

#

model.add(Conv2D(filters = 128, kernel_size =(3,3), padding ='same', activation ='relu', kernel_regularizer = l2(weight_decay)))
model.add(BatchNormalization())
model.add(Conv2D(filters = 128, kernel_size =(3,3), padding ='same', activation ='relu', kernel_regularizer = l2(weight_decay)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(rate = 0.4 ))


model.add(Conv2D(filters = 256, kernel_size =(3,3), padding ='same', activation ='relu', kernel_regularizer = l2(weight_decay)))
model.add(BatchNormalization())
model.add(Conv2D(filters = 256, kernel_size =(3,3), padding ='same', activation ='relu', kernel_regularizer = l2(weight_decay)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Dropout(rate = 0.5))

# Flatten the tensor output

model.add(Flatten())

# fully connected layer
model.add(Dense(10, activation = 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 32, 32, 32)        896
#
#  batch_normalization_8 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_9 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 16, 16, 32)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_10 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  conv2d_11 (Conv2D)          (None, 16, 16, 64)        36928
#
#  batch_normalization_11 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_12 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  conv2d_13 (Conv2D)          (None, 8, 8, 128)         147584
#
#  batch_normalization_13 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  max_pooling2d_6 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 4, 4, 128)         0
#
#  conv2d_14 (Conv2D)          (None, 4, 4, 256)         295168
#
#  batch_normalization_14 (Ba  (None, 4, 4, 256)         1024
#  tchNormalization)
#
#  conv2d_15 (Conv2D)          (None, 4, 4, 256)         590080
#
#  batch_normalization_15 (Ba  (None, 4, 4, 256)         1024
#  tchNormalization)
#
#  max_pooling2d_7 (MaxPoolin  (None, 2, 2, 256)         0
#  g2D)
#
#  dropout_7 (Dropout)         (None, 2, 2, 256)         0
#
#  flatten_1 (Flatten)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 1186346 (4.53 MB)
# Trainable params: 1184426 (4.52 MB)
# Non-trainable params: 1920 (7.50 KB)
# _________________________________________________________________

# %%
# set the batch size
batch_size = 64
epoch = 50
optimizer = Adam(learning_rate = 0.0005)
model.compile(optimizer = optimizer, loss = 'categorical_crossentropy', metrics = ['accuracy'])

reduce_lr=ReduceLROnPlateau(monitor ='val_loss', factor = 0.5, patience =10, min_lr = 0.00001)

early_stopping = EarlyStopping(monitor = 'val_loss', patience = 40, restore_best_weights = True, verbose=1 )

model.fit(data_generator.flow(X_train, y_train, batch_size= batch_size), epochs = epoch, validation_data = (X_valid, y_valid),
                             callbacks = [reduce_lr, early_stopping])
# Out:
# Epoch 1/50
# 704/704 [==============================] - 75s 103ms/step - loss: 2.3417 - accuracy: 0.3371 - val_loss: 1.8588 - val_accuracy: 0.4434 - lr: 5.0000e-04
# Epoch 2/50
# 704/704 [==============================] - 70s 100ms/step - loss: 1.6926 - accuracy: 0.4669 - val_loss: 1.6941 - val_accuracy: 0.4774 - lr: 5.0000e-04
# Epoch 3/50
# 704/704 [==============================] - 70s 99ms/step - loss: 1.4697 - accuracy: 0.5318 - val_loss: 1.6391 - val_accuracy: 0.5580 - lr: 5.0000e-04
# Epoch 4/50
# 704/704 [==============================] - 79s 112ms/step - loss: 1.3123 - accuracy: 0.5793 - val_loss: 1.1568 - val_accuracy: 0.6470 - lr: 5.0000e-04
# Epoch 5/50
# 704/704 [==============================] - 80s 114ms/step - loss: 1.1927 - accuracy: 0.6200 - val_loss: 1.0936 - val_accuracy: 0.6660 - lr: 5.0000e-04
# Epoch 6/50
# 704/704 [==============================] - 82s 117ms/step - loss: 1.1045 - accuracy: 0.6537 - val_loss: 0.9351 - val_accuracy: 0.7150 - lr: 5.0000e-04
# Epoch 7/50
# 704/704 [==============================] - 81s 114ms/step - loss: 1.0349 - accuracy: 0.6789 - val_loss: 0.8848 - val_accuracy: 0.7390 - lr: 5.0000e-04
# Epoch 8/50
# 704/704 [==============================] - 77s 109ms/step - loss: 0.9953 - accuracy: 0.6950 - val_loss: 0.8724 - val_accuracy: 0.7442 - lr: 5.0000e-04
# Epoch 9/50
# 704/704 [==============================] - 72s 103ms/step - loss: 0.9592 - accuracy: 0.7109 - val_loss: 0.8272 - val_accuracy: 0.7592 - lr: 5.0000e-04
# Epoch 10/50
# 704/704 [==============================] - 83s 118ms/step - loss: 0.9274 - accuracy: 0.7237 - val_loss: 0.9220 - val_accuracy: 0.7476 - lr: 5.0000e-04
# Epoch 11/50
50
# 704/704 [==============================] - 72s 102ms/step - loss: 0.5893 - accuracy: 0.8607 - val_loss: 0.5441 - val_accuracy: 0.8792 - lr: 2.5000e-04
# Epoch 48/50
# 704/704 [==============================] - 71s 101ms/step - loss: 0.5841 - accuracy: 0.8607 - val_loss: 0.5337 - val_accuracy: 0.8806 - lr: 2.5000e-04
# Epoch 49/50
# 704/704 [==============================] - 72s 103ms/step - loss: 0.5797 - accuracy: 0.8614 - val_loss: 0.5266 - val_accuracy: 0.8834 - lr: 2.5000e-04
# Epoch 50/50
# 704/704 [==============================] - 72s 102ms/step - loss: 0.5806 - accuracy: 0.8606 - val_loss: 0.5369 - val_accuracy: 0.8816 - lr: 2.5000e-04

# %%
# X_train
# Out:
# array([[[[-0.68103355,  0.05164081,  1.1428579 ],
#          [-0.68103355,  0.03605199,  1.1272691 ],
#          [-0.68103355,  0.05164081,  1.1272691 ],
#          ...,
#          [ 0.08281844,  0.14517371,  0.36341715],
#          [ 0.56607175,  0.64401585,  0.8934369 ],
#          [ 0.86225927,  1.0493251 ,  1.4078678 ]],
#
#         [[-0.6342671 ,  0.09840726,  1.1896244 ],
#          [-0.6498559 ,  0.08281844,  1.1740355 ],
#          [-0.6498559 ,  0.08281844,  1.1896244 ],
#          ...,
#          [-0.19778025, -0.13542499,  0.08281844],
#          [ 0.1295849 ,  0.2542954 ,  0.6907823 ],
#          [ 0.6907823 ,  0.92461455,  1.4702231 ]],
#
#         [[-0.6186783 ,  0.11399607,  1.2208021 ],
#          [-0.6186783 ,  0.11399607,  1.1896244 ],
#          [-0.6186783 ,  0.11399607,  1.2052132 ],
#          ...,
#          [-0.49396777, -0.41602367, -0.26013553],
#          [-0.1510138 ,  0.03605199,  0.41018358],
#          [ 0.26988423,  0.5972494 ,  1.1428579 ]],
#
#         ...,
#
#         [[ 1.1740355 ,  0.84667045,  0.30106187],
#          [ 0.94020337,  0.64401585,  0.1295849 ],
#          [ 0.86225927,  0.58166057,  0.08281844],
#          ...,
#          [ 0.48812768,  0.37900597,  0.1295849 ],
#          [ 1.5793449 ,  1.4078678 ,  1.0337362 ],
#          [ 1.5793449 ,  1.3455126 ,  0.94020337]],
#
#         [[ 1.1116803 ,  0.799904  ,  0.2387066 ],
#          [ 0.8934369 ,  0.5504829 , -0.04189209],
#          [ 0.799904  ,  0.47253886, -0.10424735],
#          ...,
#          [ 0.17635134,  0.06722963, -0.10424735],
#          [ 0.628427  ,  0.50371647,  0.26988423],
#          [ 0.8934369 ,  0.70637107,  0.37900597]],
#
#         [[ 1.0337362 ,  0.76872635,  0.17635134],
#          [ 1.0025586 ,  0.65960467,  0.02046318],
#          [ 0.8310816 ,  0.50371647, -0.13542499],
#          ...,
#          [-0.05748091, -0.18219143, -0.47837895],
#          [ 0.1295849 ,  0.00487436, -0.32249078],
#          [ 0.50371647,  0.34782833, -0.07306972]]],
#
#
#        [[[ 1.7196442 ,  1.7196442 ,  1.8443547 ],
#          [ 1.6728777 ,  1.6728777 ,  1.7975882 ],
#          [ 1.5014007 ,  1.5325783 ,  1.6417    ],
#          ...,
#          [ 0.05164081, -0.02630327,  0.14517371],
#          [ 0.02046318, -0.05748091,  0.09840726],
#          [-0.01071446, -0.08865854,  0.08281844]],
#
#         [[ 1.7819995 ,  1.7819995 ,  1.9067099 ],
#          [ 1.6728777 ,  1.6728777 ,  1.7975882 ],
#          [ 0.76872635,  0.76872635,  0.8934369 ],
#          ...,
#          [-0.07306972, -0.11983617,  0.11399607],
#          [-0.07306972, -0.11983617,  0.11399607],
#          [-0.10424735, -0.1510138 ,  0.09840726]],
#
#         [[ 1.7664106 ,  1.7819995 ,  1.8755324 ],
#          [ 1.6728777 ,  1.6572889 ,  1.7508218 ],
#          [ 0.2387066 ,  0.19194016,  0.30106187],
#          ...,
#          [ 0.08281844,  0.08281844,  0.37900597],
#          [ 0.11399607,  0.09840726,  0.39459476],
#          [ 0.11399607,  0.09840726,  0.41018358]],
#
#         ...,
#
#         [[ 0.86225927,  0.76872635,  0.26988423],
#          [ 0.70637107,  0.6128382 ,  0.06722963],
#          [ 0.78431517,  0.6907823 ,  0.20752898],
#          ...,
#          [ 0.65960467,  0.22311778, -0.21336907],
#          [ 0.628427  ,  0.16076252, -0.18219143],
#          [ 0.50371647,  0.06722963, -0.22895789]],
#
#         [[ 0.8310816 ,  0.78431517,  0.28547305],
#          [ 0.76872635,  0.70637107,  0.19194016],
#          [ 0.70637107,  0.6128382 ,  0.1295849 ],
#          ...,
#          [ 0.5504829 ,  0.2542954 , -0.22895789],
#          [ 0.45695004,  0.11399607, -0.27572432],
#          [ 0.36341715,  0.00487436, -0.35366842]],
#
#         [[ 0.6751935 ,  0.64401585,  0.1295849 ],
#          [ 0.7219599 ,  0.65960467,  0.16076252],
#          [ 0.70637107,  0.6128382 ,  0.11399607],
#          ...,
#          [ 0.5193053 ,  0.28547305, -0.21336907],
#          [ 0.44136122,  0.16076252, -0.26013553],
#          [ 0.39459476,  0.06722963, -0.30690196]]],
#
#
#        [[[-1.3669415 , -1.242231  , -1.1019316 ],
#          [-1.320175  , -1.1642869 , -1.0395763 ],
#          [-1.2889974 , -1.1175205 , -0.9772211 ],
#          ...,
#          [-1.0863428 , -0.8057441 , -0.5875007 ],
#          [-1.1954645 , -0.9148658 , -0.7122112 ],
#          [-1.2734085 , -1.0083987 , -0.83692175]],
#
#         [[-1.3513527 , -1.1798757 , -1.0863428 ],
#          [-1.3045862 , -1.1486981 , -1.0395763 ],
#          [-1.2110534 , -1.0707539 , -0.94604343],
#          ...,
#          [-1.2110534 , -0.86809933, -0.68103355],
#          [-1.242231  , -0.9304546 , -0.75897765],
#          [-1.2734085 , -0.9928099 , -0.8525106 ]],
#
#         [[-1.2266421 , -1.0395763 , -0.96163225],
#          [-1.1954645 , -1.0551652 , -0.96163225],
#          [-0.9928099 , -0.899277  , -0.7901553 ],
#          ...,
#          [-1.242231  , -0.88368815, -0.7122112 ],
#          [-1.3045862 , -0.9772211 , -0.83692175],
#          [-1.2734085 , -1.0239875 , -0.9148658 ]],
#
#         ...,
#
#         [[ 0.00487436,  0.20752898,  0.30106187],
#          [-0.01071446,  0.19194016,  0.28547305],
#          [ 0.09840726,  0.30106187,  0.39459476],
#          ...,
#          [-1.1954645 , -1.0707539 , -1.0707539 ],
#          [-0.46279013, -0.32249078, -0.30690196],
#          [-0.94604343, -0.7901553 , -0.7745665 ]],
#
#         [[ 0.16076252,  0.36341715,  0.45695004],
#          ...,
#          [ 1.4546343 ,  1.4234567 ,  1.4702231 ],
#          [ 1.4702231 ,  1.4390454 ,  1.485812  ],
#          [ 1.4234567 ,  1.392279  ,  1.4390454 ]],
#
#         [[ 1.2208021 ,  1.2052132 ,  1.3455126 ],
#          [ 1.2208021 ,  1.2052132 ,  1.2987461 ],
#          [ 1.2675685 ,  1.2519797 ,  1.3299237 ],
#          ...,
#          [ 1.4546343 ,  1.4234567 ,  1.4702231 ],
#          [ 1.4234567 ,  1.392279  ,  1.4390454 ],
#          [ 1.392279  ,  1.3611014 ,  1.4078678 ]],
#
#         [[ 1.1584468 ,  1.1428579 ,  1.2675685 ],
#          [ 1.1896244 ,  1.1740355 ,  1.2675685 ],
#          [ 1.2363908 ,  1.2208021 ,  1.2987461 ],
#          ...,
#          [ 1.5014007 ,  1.4702231 ,  1.5169896 ],
#          [ 1.4390454 ,  1.4078678 ,  1.4546343 ],
#          [ 1.4234567 ,  1.392279  ,  1.4390454 ]]]], dtype=float32)

# %%
model.save('cifar.h5')

model.save('cifar.keras')
# Out:
# C:\Users\iftek\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Visualizing the learning curves

# %%
plt.figure(figsize=(15,6))

plt.subplot(1, 2, 1)
plt.plot(model.history.history['loss'], label='Train_loss', color ='blue')
plt.plot(model.history.history['val_loss'], label = 'Validation Loss', color = 'red')
plt.legend()
plt.title('Loss Evaluation')

plt.figure(figsize=(15,6))
plt.subplot(1, 2, 1)
plt.plot(model.history.history['accuracy'], label='Train Accuracy', color ='blue')
plt.plot(model.history.history['val Accuracy'], label = 'Validation Accuracy', color = 'red')
plt.legend()
plt.title('Accuracy Evaluation')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 12
#      10 plt.subplot(1, 2, 1)
#      11 plt.plot(model.history.history['accuracy'], label='Train Accuracy', color ='blue')
# ---> 12 plt.plot(model.history.history['val Accuracy'], label = 'Validation Accuracy', color = 'red')
#      13 plt.legend()
#      14 plt.title('Accuracy Evaluation')
#
# KeyError: 'val Accuracy'

# %% [markdown]
# ## Evaluating the Optimal Model on Test Data

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)

print(f"Test accuracy : {test_acc} \n TestLoss : {test_loss}")
# Out:
# 313/313 [==============================] - 7s 21ms/step - loss: 0.5674 - accuracy: 0.8699
# Test accuracy : 0.8698999881744385
#  TestLoss : 0.5674170255661011

# %% [markdown]
# ## Performance on an out of DatasetImage

# %%
url = 'https://pxhere.com/en/photo/1353073'
reps = urllib.request.urlopen(url)
image = np.asarray(bytearray(reps.read()), dtype='uint8')
image = cv2.imdecode(image, cv2.IMREAD_UNCHANGED)

# cv2.cvtColor(image, cv2.cvtColor_BGR2RGB)

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.show
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[40], line 8
#       4 image = cv2.imdecode(image, cv2.IMREAD_UNCHANGED)
#       6 # cv2.cvtColor(image, cv2.cvtColor_BGR2RGB)
# ----> 8 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#      10 plt.imshow(image)
#      11 plt.show
#
# error: OpenCV(4.12.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
image.shape

# %%
# converting 32 * 32
image = cv2.resize(image, (32, 32))

# normalize the image
image = (image - mean)/(std+.00000001)

# add a dimension
image = image.reshape((1, 32, 32, 3))

# %%
predict = model.predict(image)
predict

# %%
class_names[predict.argmax()]
